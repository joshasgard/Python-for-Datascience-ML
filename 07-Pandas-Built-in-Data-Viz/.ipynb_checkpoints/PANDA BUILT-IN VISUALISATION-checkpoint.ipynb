# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

#Use this for quick histogram and line plots, heavy customoization 
#and other plots should be done with Seaborn

# %%
df1=pd.read_csv('df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2=pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist(bins=30)

# %%
#df1['A'].plot(kind='hist',bins=40) or
df1['A'].plot.hist()

# %%
df2.plot.area(alpha=0.4)
#alpha is for plot transparency

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.line(x= df1.index,y='B', figsize=(12,3),lw=1)

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*50)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df =pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
df
# Out:
#             a         b
# 0   -0.610472  0.244047
# 1   -0.168148 -0.999029
# 2    0.033054 -0.119702
# 3   -0.301068 -0.101138
# 4   -0.194877  0.269549
# ..        ...       ...
# 995 -2.435178 -0.984692
# 996  0.945856  0.394194
# 997 -0.011423  1.189797
# 998  2.347458 -0.500479
# 999  1.400615  0.701462
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='a',y='b',gridsize=30,cmap='coolwarm')

# %%
#df2['a'].plot.kde() or
df2.plot.density()
