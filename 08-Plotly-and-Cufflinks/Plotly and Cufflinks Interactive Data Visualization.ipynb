# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 4.8.1

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

#plotly connects pandas and python to an interactive Javascript Library

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# DATA
df =pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -1.185979 -1.016245 -1.294544 -0.045763
# 1 -0.301803  0.724573  0.387984 -2.521406
# 2  1.186806  1.374678  1.572514  1.703281
# 3 -2.120723  0.362285 -1.485616  0.690644
# 4 -0.650309 -1.768220  0.230602 -0.551554

# %%
df2 = pd.DataFrame({'Category' :['A','B','C'], 'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
#df.plot()
df.iplot()
# Out:
# <div>
#
#
#             <div id="2f8238e6-ac9d-4a4b-b0db-e7adbb44da02" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2f8238e6-ac9d-4a4b-b0db-e7adbb44da02")) {
#                     Plotly.newPlot(
#                         '2f8238e6-ac9d-4a4b-b0db-e7adbb44da02',
# ...

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=30)
# Out:
# <div>
#
#
#             <div id="622c14b7-1196-47e1-8a7d-cee978b3bbc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("622c14b7-1196-47e1-8a7d-cee978b3bbc1")) {
#                     Plotly.newPlot(
#                         '622c14b7-1196-47e1-8a7d-cee978b3bbc1',
# ...

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>
#
#
#             <div id="001e0cd6-0f02-4ea8-a194-b896aa119d9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("001e0cd6-0f02-4ea8-a194-b896aa119d9d")) {
#                     Plotly.newPlot(
#                         '001e0cd6-0f02-4ea8-a194-b896aa119d9d',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="61798cf6-5432-485a-86cd-e6d3f14b804f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("61798cf6-5432-485a-86cd-e6d3f14b804f")) {
#                     Plotly.newPlot(
#                         '61798cf6-5432-485a-86cd-e6d3f14b804f',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [-2.2835965776166134, 28.086438714851507, 1.6760584856744496, 1.2527885449929892]}],
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="0046aa41-a478-4a1f-8d22-9902059279b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0046aa41-a478-4a1f-8d22-9902059279b0")) {
#                     Plotly.newPlot(
#                         '0046aa41-a478-4a1f-8d22-9902059279b0',
# ...

# %%
df3=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],
                  'z':[5,4,3,2,1]})

# %%
df3.iplot(kind='surface',colorscale='rdylbu')

#check plotly documentation for colorscale codes for surface plots
# Out:
# <div>
#
#
#             <div id="e57dfbb3-1d61-4a54-ac2e-f6ffa7cd990d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e57dfbb3-1d61-4a54-ac2e-f6ffa7cd990d")) {
#                     Plotly.newPlot(
#                         'e57dfbb3-1d61-4a54-ac2e-f6ffa7cd990d',
# ...

# %%
df.iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="4ede80f5-60ef-4914-b52a-9f8de9f0cdf3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4ede80f5-60ef-4914-b52a-9f8de9f0cdf3")) {
#                     Plotly.newPlot(
#                         '4ede80f5-60ef-4914-b52a-9f8de9f0cdf3',
# ...

# %%
df[['A','B']].iplot(kind='spread')
#spreadplot is good for analysing financial data,
#e.g spread betweeen 2 stocks
# Out:
# <div>
#
#
#             <div id="956a128f-fdb0-47ff-9602-a556e88efa66" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("956a128f-fdb0-47ff-9602-a556e88efa66")) {
#                     Plotly.newPlot(
#                         '956a128f-fdb0-47ff-9602-a556e88efa66',
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
#quite common UN and other agency reports
# Out:
# <div>
#
#
#             <div id="912cb5fa-7fde-46d9-9191-514f2ee17a7c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("912cb5fa-7fde-46d9-9191-514f2ee17a7c")) {
#                     Plotly.newPlot(
#                         '912cb5fa-7fde-46d9-9191-514f2ee17a7c',
# ...

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="38ee1d2e-5923-4131-a449-e29f1725c28f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("38ee1d2e-5923-4131-a449-e29f1725c28f")) {
#                     Plotly.newPlot(
#                         '38ee1d2e-5923-4131-a449-e29f1725c28f',
# ...
